# %%
import numpy as np
import pandas as pd
import math
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Outline
#
# ## Part A. Combining Data By Year
# 1. Import each year's total units by puma csv and aggregate by income levels and drop detailed numbers
# 2. Merge across years
# 3. Repeat for recent units
#
# ## Part B. Imputing Data Down to City-Level
# 1.

# %% [markdown]
# ## Part A1. Import each year's total units by puma csv

# %%
#Version for at Terner Center
y18_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2018 Analysis/weighted_puma_counts.csv", delimiter=",")

#Version for on laptop
#y18_df=pd.read_csv("C:/Users/jonst/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2018 Analysis/weighted_puma_counts.csv", delimiter=",")
y18_df
# Out:
#       PUMA  rent_ELI_studio_count  rent_ELI_1_br_count  rent_ELI_2_br_count  \
# 0      101                 205.00              1604.00              1840.00
# 1      102                2790.00              4483.00              1963.00
# 2      103                 541.00               798.00               212.00
# 3      104                 133.00              1217.00              2334.00
# 4      105                 278.00               800.00               424.00
# ..     ...                    ...                  ...                  ...
# 260  11103                  69.00               864.00              1304.00
# 261  11104                 934.00               488.00               158.00
# 262  11105                   0.00               446.00               882.00
# 263  11106                   0.00               178.00               202.00
# 264  11300                   0.00              1865.00              1199.00
#
# ...

# %%
# aggregate 2018 unit counts by income
y18_df["18_total_ELI_units"]=y18_df["rent_ELI_studio_count"]+y18_df["rent_ELI_1_br_count"]+y18_df["rent_ELI_2_br_count"]+y18_df["rent_ELI_3_br_count"]+y18_df["rent_ELI_4_br_count"]+y18_df["own_ELI_studio_count"]+y18_df["own_ELI_1_br_count"]+y18_df["own_ELI_2_br_count"]+y18_df["own_ELI_3_br_count"]+y18_df["own_ELI_4_br_count"]
y18_df["18_total_VLI_units"]=y18_df["rent_VLI_studio_count"]+y18_df["rent_VLI_1_br_count"]+y18_df["rent_VLI_2_br_count"]+y18_df["rent_VLI_3_br_count"]+y18_df["rent_VLI_4_br_count"]+y18_df["own_VLI_studio_count"]+y18_df["own_VLI_1_br_count"]+y18_df["own_VLI_2_br_count"]+y18_df["own_VLI_3_br_count"]+y18_df["own_VLI_4_br_count"]
y18_df["18_total_LI_units"]=y18_df["rent_LI_studio_count"]+y18_df["rent_LI_1_br_count"]+y18_df["rent_LI_2_br_count"]+y18_df["rent_LI_3_br_count"]+y18_df["rent_LI_4_br_count"]+y18_df["own_LI_studio_count"]+y18_df["own_LI_1_br_count"]+y18_df["own_LI_2_br_count"]+y18_df["own_LI_3_br_count"]+y18_df["own_LI_4_br_count"]
y18_df["18_total_MI_units"]=y18_df["rent_MI_studio_count"]+y18_df["rent_MI_1_br_count"]+y18_df["rent_MI_2_br_count"]+y18_df["rent_MI_3_br_count"]+y18_df["rent_MI_4_br_count"]+y18_df["own_MI_studio_count"]+y18_df["own_MI_1_br_count"]+y18_df["own_MI_2_br_count"]+y18_df["own_MI_3_br_count"]+y18_df["own_MI_4_br_count"]
y18_df["18_total_MoI_units"]=y18_df["rent_MoI_studio_count"]+y18_df["rent_MoI_1_br_count"]+y18_df["rent_MoI_2_br_count"]+y18_df["rent_MoI_3_br_count"]+y18_df["rent_MoI_4_br_count"]+y18_df["own_MoI_studio_count"]+y18_df["own_MoI_1_br_count"]+y18_df["own_MoI_2_br_count"]+y18_df["own_MoI_3_br_count"]+y18_df["own_MoI_4_br_count"]
y18_df["18_total_HI_units"]=y18_df["rent_HI_studio_count"]+y18_df["rent_HI_1_br_count"]+y18_df["rent_HI_2_br_count"]+y18_df["rent_HI_3_br_count"]+y18_df["rent_HI_4_br_count"]+y18_df["own_HI_studio_count"]+y18_df["own_HI_1_br_count"]+y18_df["own_HI_2_br_count"]+y18_df["own_HI_3_br_count"]+y18_df["own_HI_4_br_count"]
y18_totals_df=y18_df[["PUMA","18_total_ELI_units","18_total_VLI_units","18_total_LI_units","18_total_MI_units","18_total_MoI_units","18_total_HI_units"]].copy()
y18_totals_df
# Out:
#       PUMA  18_total_ELI_units  18_total_VLI_units  18_total_LI_units  \
# 0      101             3975.00             9176.00           19422.00
# 1      102            10977.00            24548.00           39684.00
# 2      103             2118.00             5731.00           14397.00
# 3      104             5108.00            14982.00           24605.00
# 4      105             2125.00             8058.00           21528.00
# ..     ...                 ...                 ...                ...
# 260  11103             2594.00             6102.00           22345.00
# 261  11104             1964.00             3983.00           18914.00
# 262  11105             1840.00             6316.00           12530.00
# 263  11106              750.00             1454.00            7767.00
# 264  11300             4741.00            15564.00           30246.00
#
#      18_total_MI_units  18_total_MoI_units  18_total_HI_units
# 0             24614.00            28766.00            3778.00
# ...

# %%
# aggregate 2017 unit counts by income
y17_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2017 Analysis/weighted_puma_counts.csv", delimiter=",")
y17_df["17_total_ELI_units"]=y17_df["rent_ELI_studio_count"]+y17_df["rent_ELI_1_br_count"]+y17_df["rent_ELI_2_br_count"]+y17_df["rent_ELI_3_br_count"]+y17_df["rent_ELI_4_br_count"]+y17_df["own_ELI_studio_count"]+y17_df["own_ELI_1_br_count"]+y17_df["own_ELI_2_br_count"]+y17_df["own_ELI_3_br_count"]+y17_df["own_ELI_4_br_count"]
y17_df["17_total_VLI_units"]=y17_df["rent_VLI_studio_count"]+y17_df["rent_VLI_1_br_count"]+y17_df["rent_VLI_2_br_count"]+y17_df["rent_VLI_3_br_count"]+y17_df["rent_VLI_4_br_count"]+y17_df["own_VLI_studio_count"]+y17_df["own_VLI_1_br_count"]+y17_df["own_VLI_2_br_count"]+y17_df["own_VLI_3_br_count"]+y17_df["own_VLI_4_br_count"]
y17_df["17_total_LI_units"]=y17_df["rent_LI_studio_count"]+y17_df["rent_LI_1_br_count"]+y17_df["rent_LI_2_br_count"]+y17_df["rent_LI_3_br_count"]+y17_df["rent_LI_4_br_count"]+y17_df["own_LI_studio_count"]+y17_df["own_LI_1_br_count"]+y17_df["own_LI_2_br_count"]+y17_df["own_LI_3_br_count"]+y17_df["own_LI_4_br_count"]
y17_df["17_total_MI_units"]=y17_df["rent_MI_studio_count"]+y17_df["rent_MI_1_br_count"]+y17_df["rent_MI_2_br_count"]+y17_df["rent_MI_3_br_count"]+y17_df["rent_MI_4_br_count"]+y17_df["own_MI_studio_count"]+y17_df["own_MI_1_br_count"]+y17_df["own_MI_2_br_count"]+y17_df["own_MI_3_br_count"]+y17_df["own_MI_4_br_count"]
y17_df["17_total_MoI_units"]=y17_df["rent_MoI_studio_count"]+y17_df["rent_MoI_1_br_count"]+y17_df["rent_MoI_2_br_count"]+y17_df["rent_MoI_3_br_count"]+y17_df["rent_MoI_4_br_count"]+y17_df["own_MoI_studio_count"]+y17_df["own_MoI_1_br_count"]+y17_df["own_MoI_2_br_count"]+y17_df["own_MoI_3_br_count"]+y17_df["own_MoI_4_br_count"]
y17_df["17_total_HI_units"]=y17_df["rent_HI_studio_count"]+y17_df["rent_HI_1_br_count"]+y17_df["rent_HI_2_br_count"]+y17_df["rent_HI_3_br_count"]+y17_df["rent_HI_4_br_count"]+y17_df["own_HI_studio_count"]+y17_df["own_HI_1_br_count"]+y17_df["own_HI_2_br_count"]+y17_df["own_HI_3_br_count"]+y17_df["own_HI_4_br_count"]
y17_totals_df=y17_df[["PUMA","17_total_ELI_units","17_total_VLI_units","17_total_LI_units","17_total_MI_units","17_total_MoI_units","17_total_HI_units"]].copy()
y17_totals_df
# Out:
#       PUMA  17_total_ELI_units  17_total_VLI_units  17_total_LI_units  \
# 0      101             2040.00             9214.00           20381.00
# 1      102             8021.00            23203.00           38621.00
# 2      103             1637.00             6092.00           12571.00
# 3      104             4021.00            14934.00           24805.00
# 4      105             3043.00             8373.00           21562.00
# ..     ...                 ...                 ...                ...
# 260  11103             3320.00             7996.00           23473.00
# 261  11104             2010.00             5597.00           16471.00
# 262  11105             1817.00             6040.00           13049.00
# 263  11106              704.00             2627.00            9254.00
# 264  11300             5043.00            14201.00           28488.00
#
#      17_total_MI_units  17_total_MoI_units  17_total_HI_units
# 0             24408.00            28298.00            4031.00
# ...

# %%
# aggregate 2016 unit counts by income
y16_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2016 Analysis/weighted_puma_counts.csv", delimiter=",")
y16_df["16_total_ELI_units"]=y16_df["rent_ELI_studio_count"]+y16_df["rent_ELI_1_br_count"]+y16_df["rent_ELI_2_br_count"]+y16_df["rent_ELI_3_br_count"]+y16_df["rent_ELI_4_br_count"]+y16_df["own_ELI_studio_count"]+y16_df["own_ELI_1_br_count"]+y16_df["own_ELI_2_br_count"]+y16_df["own_ELI_3_br_count"]+y16_df["own_ELI_4_br_count"]
y16_df["16_total_VLI_units"]=y16_df["rent_VLI_studio_count"]+y16_df["rent_VLI_1_br_count"]+y16_df["rent_VLI_2_br_count"]+y16_df["rent_VLI_3_br_count"]+y16_df["rent_VLI_4_br_count"]+y16_df["own_VLI_studio_count"]+y16_df["own_VLI_1_br_count"]+y16_df["own_VLI_2_br_count"]+y16_df["own_VLI_3_br_count"]+y16_df["own_VLI_4_br_count"]
y16_df["16_total_LI_units"]=y16_df["rent_LI_studio_count"]+y16_df["rent_LI_1_br_count"]+y16_df["rent_LI_2_br_count"]+y16_df["rent_LI_3_br_count"]+y16_df["rent_LI_4_br_count"]+y16_df["own_LI_studio_count"]+y16_df["own_LI_1_br_count"]+y16_df["own_LI_2_br_count"]+y16_df["own_LI_3_br_count"]+y16_df["own_LI_4_br_count"]
y16_df["16_total_MI_units"]=y16_df["rent_MI_studio_count"]+y16_df["rent_MI_1_br_count"]+y16_df["rent_MI_2_br_count"]+y16_df["rent_MI_3_br_count"]+y16_df["rent_MI_4_br_count"]+y16_df["own_MI_studio_count"]+y16_df["own_MI_1_br_count"]+y16_df["own_MI_2_br_count"]+y16_df["own_MI_3_br_count"]+y16_df["own_MI_4_br_count"]
y16_df["16_total_MoI_units"]=y16_df["rent_MoI_studio_count"]+y16_df["rent_MoI_1_br_count"]+y16_df["rent_MoI_2_br_count"]+y16_df["rent_MoI_3_br_count"]+y16_df["rent_MoI_4_br_count"]+y16_df["own_MoI_studio_count"]+y16_df["own_MoI_1_br_count"]+y16_df["own_MoI_2_br_count"]+y16_df["own_MoI_3_br_count"]+y16_df["own_MoI_4_br_count"]
y16_df["16_total_HI_units"]=y16_df["rent_HI_studio_count"]+y16_df["rent_HI_1_br_count"]+y16_df["rent_HI_2_br_count"]+y16_df["rent_HI_3_br_count"]+y16_df["rent_HI_4_br_count"]+y16_df["own_HI_studio_count"]+y16_df["own_HI_1_br_count"]+y16_df["own_HI_2_br_count"]+y16_df["own_HI_3_br_count"]+y16_df["own_HI_4_br_count"]
y16_totals_df=y16_df[["PUMA","16_total_ELI_units","16_total_VLI_units","16_total_LI_units","16_total_MI_units","16_total_MoI_units","16_total_HI_units"]].copy()
y16_totals_df
# Out:
#       PUMA  16_total_ELI_units  16_total_VLI_units  16_total_LI_units  \
# 0      101             2241.00             7891.00           18201.00
# 1      102            11567.00            24962.00           40656.00
# 2      103             1882.00             4642.00           12837.00
# 3      104             3783.00            12814.00           23972.00
# 4      105             3701.00            10098.00           23140.00
# ..     ...                 ...                 ...                ...
# 260  11103             2096.00             7006.00           22259.00
# 261  11104             2040.00             3847.00           16039.00
# 262  11105              973.00             7177.00           14795.00
# 263  11106              796.00             2528.00           10560.00
# 264  11300             3312.00            13438.00           32908.00
#
#      16_total_MI_units  16_total_MoI_units  16_total_HI_units
# 0             24493.00            28448.00            4605.00
# ...

# %%
# aggregate 2015 unit counts by income
y15_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2015 Analysis/weighted_puma_counts.csv", delimiter=",")
y15_df["15_total_ELI_units"]=y15_df["rent_ELI_studio_count"]+y15_df["rent_ELI_1_br_count"]+y15_df["rent_ELI_2_br_count"]+y15_df["rent_ELI_3_br_count"]+y15_df["rent_ELI_4_br_count"]+y15_df["own_ELI_studio_count"]+y15_df["own_ELI_1_br_count"]+y15_df["own_ELI_2_br_count"]+y15_df["own_ELI_3_br_count"]+y15_df["own_ELI_4_br_count"]
y15_df["15_total_VLI_units"]=y15_df["rent_VLI_studio_count"]+y15_df["rent_VLI_1_br_count"]+y15_df["rent_VLI_2_br_count"]+y15_df["rent_VLI_3_br_count"]+y15_df["rent_VLI_4_br_count"]+y15_df["own_VLI_studio_count"]+y15_df["own_VLI_1_br_count"]+y15_df["own_VLI_2_br_count"]+y15_df["own_VLI_3_br_count"]+y15_df["own_VLI_4_br_count"]
y15_df["15_total_LI_units"]=y15_df["rent_LI_studio_count"]+y15_df["rent_LI_1_br_count"]+y15_df["rent_LI_2_br_count"]+y15_df["rent_LI_3_br_count"]+y15_df["rent_LI_4_br_count"]+y15_df["own_LI_studio_count"]+y15_df["own_LI_1_br_count"]+y15_df["own_LI_2_br_count"]+y15_df["own_LI_3_br_count"]+y15_df["own_LI_4_br_count"]
y15_df["15_total_MI_units"]=y15_df["rent_MI_studio_count"]+y15_df["rent_MI_1_br_count"]+y15_df["rent_MI_2_br_count"]+y15_df["rent_MI_3_br_count"]+y15_df["rent_MI_4_br_count"]+y15_df["own_MI_studio_count"]+y15_df["own_MI_1_br_count"]+y15_df["own_MI_2_br_count"]+y15_df["own_MI_3_br_count"]+y15_df["own_MI_4_br_count"]
y15_df["15_total_MoI_units"]=y15_df["rent_MoI_studio_count"]+y15_df["rent_MoI_1_br_count"]+y15_df["rent_MoI_2_br_count"]+y15_df["rent_MoI_3_br_count"]+y15_df["rent_MoI_4_br_count"]+y15_df["own_MoI_studio_count"]+y15_df["own_MoI_1_br_count"]+y15_df["own_MoI_2_br_count"]+y15_df["own_MoI_3_br_count"]+y15_df["own_MoI_4_br_count"]
y15_df["15_total_HI_units"]=y15_df["rent_HI_studio_count"]+y15_df["rent_HI_1_br_count"]+y15_df["rent_HI_2_br_count"]+y15_df["rent_HI_3_br_count"]+y15_df["rent_HI_4_br_count"]+y15_df["own_HI_studio_count"]+y15_df["own_HI_1_br_count"]+y15_df["own_HI_2_br_count"]+y15_df["own_HI_3_br_count"]+y15_df["own_HI_4_br_count"]
y15_totals_df=y15_df[["PUMA","15_total_ELI_units","15_total_VLI_units","15_total_LI_units","15_total_MI_units","15_total_MoI_units","15_total_HI_units"]].copy()
y15_totals_df
# Out:
#       PUMA  15_total_ELI_units  15_total_VLI_units  15_total_LI_units  \
# 0      101             2255.00             7053.00           18073.00
# 1      102             9152.00            22843.00           42468.00
# 2      103             2203.00             5778.00           14710.00
# 3      104             6047.00            15845.00           24967.00
# 4      105             1567.00             7401.00           25476.00
# ..     ...                 ...                 ...                ...
# 260  11103             2727.00             6860.00           23874.00
# 261  11104             2053.00             4855.00           17170.00
# 262  11105             1533.00             7074.00           13028.00
# 263  11106              629.00             2493.00           11429.00
# 264  11300             4420.00            13833.00           30757.00
#
#      15_total_MI_units  15_total_MoI_units  15_total_HI_units
# 0             26413.00            30369.00            1960.00
# ...

# %%
# aggregate 2014 unit counts by income
y14_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2014 Analysis/weighted_puma_counts.csv", delimiter=",")
y14_df["14_total_ELI_units"]=y14_df["rent_ELI_studio_count"]+y14_df["rent_ELI_1_br_count"]+y14_df["rent_ELI_2_br_count"]+y14_df["rent_ELI_3_br_count"]+y14_df["rent_ELI_4_br_count"]+y14_df["own_ELI_studio_count"]+y14_df["own_ELI_1_br_count"]+y14_df["own_ELI_2_br_count"]+y14_df["own_ELI_3_br_count"]+y14_df["own_ELI_4_br_count"]
y14_df["14_total_VLI_units"]=y14_df["rent_VLI_studio_count"]+y14_df["rent_VLI_1_br_count"]+y14_df["rent_VLI_2_br_count"]+y14_df["rent_VLI_3_br_count"]+y14_df["rent_VLI_4_br_count"]+y14_df["own_VLI_studio_count"]+y14_df["own_VLI_1_br_count"]+y14_df["own_VLI_2_br_count"]+y14_df["own_VLI_3_br_count"]+y14_df["own_VLI_4_br_count"]
y14_df["14_total_LI_units"]=y14_df["rent_LI_studio_count"]+y14_df["rent_LI_1_br_count"]+y14_df["rent_LI_2_br_count"]+y14_df["rent_LI_3_br_count"]+y14_df["rent_LI_4_br_count"]+y14_df["own_LI_studio_count"]+y14_df["own_LI_1_br_count"]+y14_df["own_LI_2_br_count"]+y14_df["own_LI_3_br_count"]+y14_df["own_LI_4_br_count"]
y14_df["14_total_MI_units"]=y14_df["rent_MI_studio_count"]+y14_df["rent_MI_1_br_count"]+y14_df["rent_MI_2_br_count"]+y14_df["rent_MI_3_br_count"]+y14_df["rent_MI_4_br_count"]+y14_df["own_MI_studio_count"]+y14_df["own_MI_1_br_count"]+y14_df["own_MI_2_br_count"]+y14_df["own_MI_3_br_count"]+y14_df["own_MI_4_br_count"]
y14_df["14_total_MoI_units"]=y14_df["rent_MoI_studio_count"]+y14_df["rent_MoI_1_br_count"]+y14_df["rent_MoI_2_br_count"]+y14_df["rent_MoI_3_br_count"]+y14_df["rent_MoI_4_br_count"]+y14_df["own_MoI_studio_count"]+y14_df["own_MoI_1_br_count"]+y14_df["own_MoI_2_br_count"]+y14_df["own_MoI_3_br_count"]+y14_df["own_MoI_4_br_count"]
y14_df["14_total_HI_units"]=y14_df["rent_HI_studio_count"]+y14_df["rent_HI_1_br_count"]+y14_df["rent_HI_2_br_count"]+y14_df["rent_HI_3_br_count"]+y14_df["rent_HI_4_br_count"]+y14_df["own_HI_studio_count"]+y14_df["own_HI_1_br_count"]+y14_df["own_HI_2_br_count"]+y14_df["own_HI_3_br_count"]+y14_df["own_HI_4_br_count"]
y14_totals_df=y14_df[["PUMA","14_total_ELI_units","14_total_VLI_units","14_total_LI_units","14_total_MI_units","14_total_MoI_units","14_total_HI_units"]].copy()
y14_totals_df
# Out:
#       PUMA  14_total_ELI_units  14_total_VLI_units  14_total_LI_units  \
# 0      101             2269.00             7636.00           18965.00
# 1      102             8702.00            24604.00           43381.00
# 2      103             2122.00             5550.00           13627.00
# 3      104             5536.00            15996.00           23089.00
# 4      105             2764.00             7544.00           24282.00
# ..     ...                 ...                 ...                ...
# 260  11103             2788.00             6873.00           22509.00
# 261  11104             2111.00             5807.00           17570.00
# 262  11105             1608.00             6132.00           12313.00
# 263  11106             1032.00             2241.00            9875.00
# 264  11300             2395.00            14190.00           31920.00
#
#      14_total_MI_units  14_total_MoI_units  14_total_HI_units
# 0             27272.00            28746.00             900.00
# ...

# %%
# aggregate 2013 unit counts by income
y13_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2013 Analysis/weighted_puma_counts.csv", delimiter=",")
y13_df["13_total_ELI_units"]=y13_df["rent_ELI_studio_count"]+y13_df["rent_ELI_1_br_count"]+y13_df["rent_ELI_2_br_count"]+y13_df["rent_ELI_3_br_count"]+y13_df["rent_ELI_4_br_count"]+y13_df["own_ELI_studio_count"]+y13_df["own_ELI_1_br_count"]+y13_df["own_ELI_2_br_count"]+y13_df["own_ELI_3_br_count"]+y13_df["own_ELI_4_br_count"]
y13_df["13_total_VLI_units"]=y13_df["rent_VLI_studio_count"]+y13_df["rent_VLI_1_br_count"]+y13_df["rent_VLI_2_br_count"]+y13_df["rent_VLI_3_br_count"]+y13_df["rent_VLI_4_br_count"]+y13_df["own_VLI_studio_count"]+y13_df["own_VLI_1_br_count"]+y13_df["own_VLI_2_br_count"]+y13_df["own_VLI_3_br_count"]+y13_df["own_VLI_4_br_count"]
y13_df["13_total_LI_units"]=y13_df["rent_LI_studio_count"]+y13_df["rent_LI_1_br_count"]+y13_df["rent_LI_2_br_count"]+y13_df["rent_LI_3_br_count"]+y13_df["rent_LI_4_br_count"]+y13_df["own_LI_studio_count"]+y13_df["own_LI_1_br_count"]+y13_df["own_LI_2_br_count"]+y13_df["own_LI_3_br_count"]+y13_df["own_LI_4_br_count"]
y13_df["13_total_MI_units"]=y13_df["rent_MI_studio_count"]+y13_df["rent_MI_1_br_count"]+y13_df["rent_MI_2_br_count"]+y13_df["rent_MI_3_br_count"]+y13_df["rent_MI_4_br_count"]+y13_df["own_MI_studio_count"]+y13_df["own_MI_1_br_count"]+y13_df["own_MI_2_br_count"]+y13_df["own_MI_3_br_count"]+y13_df["own_MI_4_br_count"]
y13_df["13_total_MoI_units"]=y13_df["rent_MoI_studio_count"]+y13_df["rent_MoI_1_br_count"]+y13_df["rent_MoI_2_br_count"]+y13_df["rent_MoI_3_br_count"]+y13_df["rent_MoI_4_br_count"]+y13_df["own_MoI_studio_count"]+y13_df["own_MoI_1_br_count"]+y13_df["own_MoI_2_br_count"]+y13_df["own_MoI_3_br_count"]+y13_df["own_MoI_4_br_count"]
y13_df["13_total_HI_units"]=y13_df["rent_HI_studio_count"]+y13_df["rent_HI_1_br_count"]+y13_df["rent_HI_2_br_count"]+y13_df["rent_HI_3_br_count"]+y13_df["rent_HI_4_br_count"]+y13_df["own_HI_studio_count"]+y13_df["own_HI_1_br_count"]+y13_df["own_HI_2_br_count"]+y13_df["own_HI_3_br_count"]+y13_df["own_HI_4_br_count"]
y13_totals_df=y13_df[["PUMA","13_total_ELI_units","13_total_VLI_units","13_total_LI_units","13_total_MI_units","13_total_MoI_units","13_total_HI_units"]].copy()
y13_totals_df
# Out:
#       PUMA  13_total_ELI_units  13_total_VLI_units  13_total_LI_units  \
# 0      101             3274.00             8409.00           17980.00
# 1      102            11107.00            29215.00           45718.00
# 2      103             2264.00             6140.00           13971.00
# 3      104             3382.00            16194.00           23402.00
# 4      105             3486.00            11640.00           25787.00
# ..     ...                 ...                 ...                ...
# 260  11103             2543.00             7943.00           21823.00
# 261  11104             3250.00             6271.00           18270.00
# 262  11105             1711.00             4074.00           10621.00
# 263  11106              687.00             1436.00            9072.00
# 264  11300             2798.00            17275.00           31371.00
#
#      13_total_MI_units  13_total_MoI_units  13_total_HI_units
# 0             27586.00            30354.00             841.00
# ...

# %%
# aggregate 2012 unit counts by income
y12_df=pd.read_csv("C:/Users/Terner GSR/Box/Cost of Doing Nothing/Climate Impacts/Data/PUMS/2012 Analysis/weighted_puma_counts.csv", delimiter=",")
y12_df["12_total_ELI_units"]=y12_df["rent_ELI_studio_count"]+y12_df["rent_ELI_1_br_count"]+y12_df["rent_ELI_2_br_count"]+y12_df["rent_ELI_3_br_count"]+y12_df["rent_ELI_4_br_count"]+y12_df["own_ELI_studio_count"]+y12_df["own_ELI_1_br_count"]+y12_df["own_ELI_2_br_count"]+y12_df["own_ELI_3_br_count"]+y12_df["own_ELI_4_br_count"]
y12_df["12_total_VLI_units"]=y12_df["rent_VLI_studio_count"]+y12_df["rent_VLI_1_br_count"]+y12_df["rent_VLI_2_br_count"]+y12_df["rent_VLI_3_br_count"]+y12_df["rent_VLI_4_br_count"]+y12_df["own_VLI_studio_count"]+y12_df["own_VLI_1_br_count"]+y12_df["own_VLI_2_br_count"]+y12_df["own_VLI_3_br_count"]+y12_df["own_VLI_4_br_count"]
y12_df["12_total_LI_units"]=y12_df["rent_LI_studio_count"]+y12_df["rent_LI_1_br_count"]+y12_df["rent_LI_2_br_count"]+y12_df["rent_LI_3_br_count"]+y12_df["rent_LI_4_br_count"]+y12_df["own_LI_studio_count"]+y12_df["own_LI_1_br_count"]+y12_df["own_LI_2_br_count"]+y12_df["own_LI_3_br_count"]+y12_df["own_LI_4_br_count"]
y12_df["12_total_MI_units"]=y12_df["rent_MI_studio_count"]+y12_df["rent_MI_1_br_count"]+y12_df["rent_MI_2_br_count"]+y12_df["rent_MI_3_br_count"]+y12_df["rent_MI_4_br_count"]+y12_df["own_MI_studio_count"]+y12_df["own_MI_1_br_count"]+y12_df["own_MI_2_br_count"]+y12_df["own_MI_3_br_count"]+y12_df["own_MI_4_br_count"]
y12_df["12_total_MoI_units"]=y12_df["rent_MoI_studio_count"]+y12_df["rent_MoI_1_br_count"]+y12_df["rent_MoI_2_br_count"]+y12_df["rent_MoI_3_br_count"]+y12_df["rent_MoI_4_br_count"]+y12_df["own_MoI_studio_count"]+y12_df["own_MoI_1_br_count"]+y12_df["own_MoI_2_br_count"]+y12_df["own_MoI_3_br_count"]+y12_df["own_MoI_4_br_count"]
y12_df["12_total_HI_units"]=y12_df["rent_HI_studio_count"]+y12_df["rent_HI_1_br_count"]+y12_df["rent_HI_2_br_count"]+y12_df["rent_HI_3_br_count"]+y12_df["rent_HI_4_br_count"]+y12_df["own_HI_studio_count"]+y12_df["own_HI_1_br_count"]+y12_df["own_HI_2_br_count"]+y12_df["own_HI_3_br_count"]+y12_df["own_HI_4_br_count"]
y12_totals_df=y12_df[["PUMA","12_total_ELI_units","12_total_VLI_units","12_total_LI_units","12_total_MI_units","12_total_MoI_units","12_total_HI_units"]].copy()
y12_totals_df
# Out:
#       PUMA  12_total_ELI_units  12_total_VLI_units  12_total_LI_units  \
# 0      101             4391.00            10965.00           22134.00
# 1      102            10081.00            29414.00           45863.00
# 2      103             2595.00             7034.00           15971.00
# 3      104             5791.00            17675.00           24422.00
# 4      105             2107.00            11267.00           26876.00
# ..     ...                 ...                 ...                ...
# 260  11103             1785.00             7461.00           21172.00
# 261  11104             1783.00             6880.00           17978.00
# 262  11105             1019.00             7073.00           13211.00
# 263  11106              410.00             2038.00            8395.00
# 264  11300             3745.00            18741.00           34128.00
#
#      12_total_MI_units  12_total_MoI_units  12_total_HI_units
# 0             28115.00            29676.00             857.00
# ...

# %% [markdown]
# ## Part A2. Merge Across Years

# %%
# merge aggregated dataframes from each year
totals_df = y12_totals_df.merge(y13_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df = totals_df.merge(y14_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df = totals_df.merge(y15_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df = totals_df.merge(y16_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df = totals_df.merge(y17_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df = totals_df.merge(y18_totals_df,how='left', left_on = "PUMA",right_on = "PUMA")
totals_df
# Out:
#       PUMA  12_total_ELI_units  12_total_VLI_units  12_total_LI_units  \
# 0      101             4391.00            10965.00           22134.00
# 1      102            10081.00            29414.00           45863.00
# 2      103             2595.00             7034.00           15971.00
# 3      104             5791.00            17675.00           24422.00
# 4      105             2107.00            11267.00           26876.00
# ..     ...                 ...                 ...                ...
# 260  11103             1785.00             7461.00           21172.00
# 261  11104             1783.00             6880.00           17978.00
# 262  11105             1019.00             7073.00           13211.00
# 263  11106              410.00             2038.00            8395.00
# 264  11300             3745.00            18741.00           34128.00
#
#      12_total_MI_units  12_total_MoI_units  12_total_HI_units  \
# 0             28115.00            29676.00             857.00
# ...

# %%
#export it
totals_df.to_csv("units_by_puma_by_year.csv")

# %% [markdown]
# ## Part B. Imputing Down to City Level

# %%
#import crosswalk file
crosswalk_df = pd.read_csv("puma_place_crosswalk.csv", delimiter=",",encoding='latin1')
crosswalk_df
# Out:
#        PUMA                     Place  puma_to_place_factor  place_code
# 0       101           Albany city, CA                  0.14         674
# 1       101         Berkeley city, CA                  0.86        6000
# 2       102       Emeryville city, CA                  0.09       22594
# 3       102          Oakland city, CA                  0.92       53000
# 4       103          Oakland city, CA                  0.93       53000
# ...     ...                       ...                   ...         ...
# 2163  11300  West Sacramento city, CA                  0.25       84816
# 2164  11300          Winters city, CA                  0.03       86034
# 2165  11300         Woodland city, CA                  0.26       86328
# 2166  11300              Yolo CDP, CA                  0.00       86804
# 2167  11300      Unincorporated_11300                  0.06       99999
#
# [2168 rows x 4 columns]

# %%
# for other computer, import totals table
units_df = pd.read_csv("units_by_puma_by_year.csv", delimiter=",",encoding='latin1')
units_df
# Out:
#      Unnamed: 0   PUMA  12_total_ELI_units  12_total_VLI_units  \
# 0             0    101             4391.00            10965.00
# 1             1    102            10081.00            29414.00
# 2             2    103             2595.00             7034.00
# 3             3    104             5791.00            17675.00
# 4             4    105             2107.00            11267.00
# ..          ...    ...                 ...                 ...
# 260         260  11103             1785.00             7461.00
# 261         261  11104             1783.00             6880.00
# 262         262  11105             1019.00             7073.00
# 263         263  11106              410.00             2038.00
# 264         264  11300             3745.00            18741.00
#
#      12_total_LI_units  12_total_MI_units  12_total_MoI_units  \
# 0             22134.00           28115.00            29676.00
# 1             45863.00           55069.00            57199.00
# ...

# %%
#merge with crosswalk file
merged_df=units_df.merge(crosswalk_df,how='left', on="PUMA")
merged_df
# Out:
#       Unnamed: 0   PUMA  12_total_ELI_units  12_total_VLI_units  \
# 0              0    101             4391.00            10965.00
# 1              0    101             4391.00            10965.00
# 2              1    102            10081.00            29414.00
# 3              1    102            10081.00            29414.00
# 4              2    103             2595.00             7034.00
# ...          ...    ...                 ...                 ...
# 2163         264  11300             3745.00            18741.00
# 2164         264  11300             3745.00            18741.00
# 2165         264  11300             3745.00            18741.00
# 2166         264  11300             3745.00            18741.00
# 2167         264  11300             3745.00            18741.00
#
#       12_total_LI_units  12_total_MI_units  12_total_MoI_units  \
# 0              22134.00           28115.00            29676.00
# 1              22134.00           28115.00            29676.00
# ...

# %%
#multiply each row's unit count by the weighting factor for that geography
merged_df["12_total_ELI_units"]=merged_df["12_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["12_total_VLI_units"]=merged_df["12_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["12_total_LI_units"]=merged_df["12_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["12_total_MI_units"]=merged_df["12_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["12_total_MoI_units"]=merged_df["12_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["12_total_HI_units"]=merged_df["12_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_ELI_units"]=merged_df["13_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_VLI_units"]=merged_df["13_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_LI_units"]=merged_df["13_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_MI_units"]=merged_df["13_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_MoI_units"]=merged_df["13_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["13_total_HI_units"]=merged_df["13_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_ELI_units"]=merged_df["14_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_VLI_units"]=merged_df["14_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_LI_units"]=merged_df["14_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_MI_units"]=merged_df["14_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_MoI_units"]=merged_df["14_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["14_total_HI_units"]=merged_df["14_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_ELI_units"]=merged_df["15_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_VLI_units"]=merged_df["15_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_LI_units"]=merged_df["15_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_MI_units"]=merged_df["15_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_MoI_units"]=merged_df["15_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["15_total_HI_units"]=merged_df["15_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_ELI_units"]=merged_df["16_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_VLI_units"]=merged_df["16_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_LI_units"]=merged_df["16_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_MI_units"]=merged_df["16_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_MoI_units"]=merged_df["16_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["16_total_HI_units"]=merged_df["16_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_ELI_units"]=merged_df["17_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_VLI_units"]=merged_df["17_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_LI_units"]=merged_df["17_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_MI_units"]=merged_df["17_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_MoI_units"]=merged_df["17_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["17_total_HI_units"]=merged_df["17_total_HI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_ELI_units"]=merged_df["18_total_ELI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_VLI_units"]=merged_df["18_total_VLI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_LI_units"]=merged_df["18_total_LI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_MI_units"]=merged_df["18_total_MI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_MoI_units"]=merged_df["18_total_MoI_units"]*merged_df["puma_to_place_factor"]
merged_df["18_total_HI_units"]=merged_df["18_total_HI_units"]*merged_df["puma_to_place_factor"]

merged_df
# Out:
#       Unnamed: 0   PUMA  12_total_ELI_units  12_total_VLI_units  \
# 0              0    101              605.96             1513.17
# 1              0    101             3785.04             9451.83
# 2              1    102              856.89             2500.19
# 3              1    102             9224.11            26913.81
# 4              2    103             2421.13             6562.72
# ...          ...    ...                 ...                 ...
# 2163         264  11300              932.50             4666.51
# 2164         264  11300              116.09              580.97
# 2165         264  11300              988.68             4947.62
# 2166         264  11300                7.49               37.48
# 2167         264  11300              205.97             1030.76
#
#       12_total_LI_units  12_total_MI_units  12_total_MoI_units  \
# 0               3054.49            3879.87             4095.29
# 1              19079.51           24235.13            25580.71
# ...

# %%
#group repeat places together
regrouped_df=merged_df.groupby("Place").sum()
regrouped_df.drop('Unnamed: 0', axis=1, inplace=True)
regrouped_df.drop('PUMA', axis=1, inplace=True)
regrouped_df.drop('puma_to_place_factor', axis=1, inplace=True)
regrouped_df.drop('place_code', axis=1, inplace=True)
regrouped_df=regrouped_df.merge(crosswalk_df,how='left', on="Place")
regrouped_df.drop('puma_to_place_factor', axis=1, inplace=True)
regrouped_df
# Out:
#                        Place  12_total_ELI_units  12_total_VLI_units  \
# 0     Acalanes Ridge CDP, CA                9.13               23.94
# 1             Acampo CDP, CA                5.18               23.36
# 2              Acton CDP, CA               34.15              228.31
# 3              Acton CDP, CA               34.15              228.31
# 4          Adelanto city, CA              227.44             2264.01
# ...                      ...                 ...                 ...
# 2163          Yreka city, CA              247.70              680.56
# 2164      Yuba City city, CA              787.18             4560.19
# 2165        Yucaipa city, CA              690.03             1921.99
# 2166   Yucca Valley town, CA              659.16             2422.38
# 2167         Zayante CDP, CA               23.40               47.07
#
#       12_total_LI_units  12_total_MI_units  12_total_MoI_units  \
# 0                 59.24             101.05              118.01
# ...

# %%
#drop duplicate rows
final_df = regrouped_df.drop_duplicates(subset = "Place")
final_df
# Out:
#                        Place  12_total_ELI_units  12_total_VLI_units  \
# 0     Acalanes Ridge CDP, CA                9.13               23.94
# 1             Acampo CDP, CA                5.18               23.36
# 2              Acton CDP, CA               34.15              228.31
# 4          Adelanto city, CA              227.44             2264.01
# 5               Adin CDP, CA                9.17               25.21
# ...                      ...                 ...                 ...
# 2163          Yreka city, CA              247.70              680.56
# 2164      Yuba City city, CA              787.18             4560.19
# 2165        Yucaipa city, CA              690.03             1921.99
# 2166   Yucca Valley town, CA              659.16             2422.38
# 2167         Zayante CDP, CA               23.40               47.07
#
#       12_total_LI_units  12_total_MI_units  12_total_MoI_units  \
# 0                 59.24             101.05              118.01
# ...

# %%
#export it
final_df.to_csv("2011-2018_unit_counts.csv")
